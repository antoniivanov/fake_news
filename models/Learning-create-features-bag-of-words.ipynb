# %%
import argparse
import pandas as pd 
import numpy as np

from sklearn.linear_model import LogisticRegression

from __future__ import print_function
import sys

def eprint(*args, **kwargs):
    print(*args, file=sys.stderr, **kwargs)

# %%
data = pd.read_csv('../data/FN_Training_Set.csv', encoding='windows-1251')

# %%
data.head(1)
# Out:
#    fake_news_score  click_bait_score  \
# 0                1                 1
#
#                                        Content Title  \
# 0  Камил Хабиб: ДАЕШ и „Ан Нусра” са нов терорист...
#
#                                          Content Url Content Published Time  \
# 0  http://a-specto.bg/kamil-habib-daesh-i-nusra-s...        17.5.2017 18:35
#
#                                              Content
# 0  Интервю на Десислава Пътева с Камил Хабиб, дек...

# %%
# %load ../feature_extraction/feature_extract.py
import re
import pandas as pd
import argparse
from numpy import *
import io
 
train_data = data
train_data.fillna(value="", inplace=True)

with io.open('../feature_extraction/bg_stopwords.txt', encoding='utf8') as f:
    stopwords = [x.strip() for x in f.readlines()]
stopwords

def sentence2wordlist(raw, language='bg+en'):
    """language: 'bg+en', 'bg', 'en', 'symbol'"""
    if language == 'bg+en':
        regex = "[^а-яА-Яa-zA-Z]"
    elif language == 'bg':
        regex = "[^а-яА-Я]"
    elif language == 'en':
        regex = "[^a-zA-Z]"
    elif language == 'symbol':
        regex = "[^-!$%^&*()_+|~=`{}\[\]:\";'<>?,.\/]"
    elif language == '!':
        regex = "[^?!]"
    clean = re.sub(regex," ", raw)
    words = clean.split()
    return words

get_number_words = lambda sent: len(sentence2wordlist(sent))

get_number_char = lambda sent: len(sent)

get_number_symbols = lambda sent: len(sentence2wordlist(sent, 'symbol'))

def get_number_stopwrods(sent):
    wordlist = sentence2wordlist(sent)
    return array(list(map(lambda x: x in stopwords, wordlist))).sum()
    
def get_avg_char_per_word(sent):
    wordlist = sentence2wordlist(sent)
    return array(list(map(len, wordlist))).mean()

def get_avg_caps_per_char(sent):
    chars_re = "[^а-яА-Яa-zA-Z]"
    # remove white spaces as well as symbols
    clean = re.sub(chars_re,"", sent)
    caps_re = "[^А-ЯA-Z]"
    caps = re.sub(caps_re, "", clean)
    try:
        return len(caps)/len(clean)
    except:
        return -1 # div by 0 case

func_list = [get_number_words, 
             get_number_char,
             get_number_symbols,
             get_number_stopwrods,
             get_avg_char_per_word,
             get_avg_caps_per_char]


col_name_ph = ["{ph}_number_words", 
             "{ph}_number_char",
             "{ph}_number_symbols",
             "{ph}_number_stopwords",
             "{ph}_avg_char_per_word",
             "{ph}_avg_caps_per_char"]

col_name = lambda s: list(map(lambda x: x.format(ph=s), col_name_ph))

def append_new_columns(df, column, name_func_dict):
    for col, func in name_func_dict.items():
        df[col] = df[column].apply(func)
    return df

train_data_extra_features = append_new_columns(train_data, 
                                               "Content Title", 
                                               dict(zip(col_name('title'),func_list)))

train_data_extra_features = append_new_columns(train_data_extra_features, 
                                               "Content", 
                                               dict(zip(col_name('body'),func_list)))
# Out:
# /Users/aivanov/anaconda/lib/python2.7/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %%
train_data = train_data_extra_features

# %%
train_data['fake_news_score_binary'] =  train_data['fake_news_score'] == 3

# %%
train_data.head(1)
# Out:
#    fake_news_score  click_bait_score  \
# 0                1                 1
#
#                                        Content Title  \
# 0  Камил Хабиб: ДАЕШ и „Ан Нусра” са нов терорист...
#
#                                          Content Url Content Published Time  \
# 0  http://a-specto.bg/kamil-habib-daesh-i-nusra-s...        17.5.2017 18:35
#
#                                              Content  title_number_char  \
# 0  Интервю на Десислава Пътева с Камил Хабиб, дек...                 58
#
#    title_avg_char_per_word  title_number_stopwords  title_number_symbols  \
# 0                      NaN                     0.0                     1
#
#    title_number_words  title_avg_caps_per_char  body_number_char  \
# 0                   0                       -1              7345
#
#    body_number_symbols  body_avg_caps_per_char  body_avg_char_per_word  \
# 0                  194                       0                     3.0
#
#    body_number_words  body_number_stopwords fake_news_score_binary
# 0                  3                    0.0                  False

# %%
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train_data, train_data["fake_news_score_binary"], \
                                                    test_size=0.25, random_state=0)
X_train.reset_index(drop=True, inplace=True);
X_test.reset_index(drop=True, inplace=True);
y_train.reset_index(drop=True, inplace=True);
y_test.reset_index(drop=True, inplace=True);

# %%
def to_words( text ):
    letters_only = re.sub(u"[^A-Яа-яa-zA-Z]", " ", text) 
    words = letters_only.lower().split()  
    stops = set(stopwords) # loaded above; lookup in set is faster than in list                
    meaningful_words = [w for w in words if not w in stops]   
    return( " ".join( meaningful_words ))   

def hist(train_data_features, vocab):
    dist = np.sum(train_data_features, axis=0)
    for tag, count in zip(vocab, dist):
        print (count, tag)

def create_features(train_data):
    clean_train_words = []
    num_rows = train_data.shape[0] 

    print (train_data.shape)
    content = train_data['Content']
    
    for i in xrange(0, num_rows):
        if( (i+1)%1000 == 0 ):
            print ("%d / %d\n" % ( i+1, num_rows ) )      
        clean_train_words.append(to_words(content[i]))
    
    from sklearn.feature_extraction.text import CountVectorizer

    # Initialize the "CountVectorizer" object, which is scikit-learn's
    # bag of words tool.  
    vectorizer = CountVectorizer(analyzer = "word",   \
                                 tokenizer = None,    \
                                 preprocessor = None, \
                                 stop_words = None,   \
                                 max_features = 5000) 
    train_data_features = vectorizer.fit_transform(clean_train_words)
    train_data_features = train_data_features.toarray()
    print(train_data_features.shape)
    vocab = vectorizer.get_feature_names()
    hist(train_data_features, vocab)
    return train_data_features

# %%
X_train_features = create_features(X_train)
# Out:
# (2111, 19)
# 1000 / 2111
#
# 2000 / 2111
#
# (2111, 5000)
# 39 advertising
# 75 amp
# 93 and
# 187 aтa
# 142 aтo
# 36 bank
# 167 baнгa
# 55 bd
# 80 be
# 68 bezistena
# 640 bg
# 49 blitz
# 77 blog
# 70 bradva
# 43 bulgaria
# 34 by
# 66 ca
# 57 caмo
# 848 ce
# 130 cfr
# 52 chemtrails
# 34 co
# 31 collins
# 322 com
# 31 comments
# 36 cyтpин
# 82 cи
# 38 cин
# 134 cлeд
# 35 cъc
# 40 daily
# 52 deep
# 34 deste
# 43 economist
# 49 eднa
# 156 facebook
# 42 google
# 119 gt
# 35 he
# 66 history
# 62 html
# 162 http
# 38 https
# 97 ii
# 46 iii
# 79 in
# 51 info
# 40 is
# 41 km
# 65 na
# 50 net
# 56 new
# 98 news
# 164 of
# 36 on
# 56 oбaчe
# 48 oгaтo
# 44 oитo
# 52 oйтo
# 37 oл
# 32 oлo
# 406 oт
# 38 oятo
# 60 pa
# 34 paз
# 125 petel
# 39 rates
# 46 rothschild
# 50 ru
# 107 skafeto
# 59 state
# 415 the
# 46 times
# 58 to
# 42 tя
# 63 us
# 35 world
# 90 www
# 41 xx
# 61 youtube
# 32 zajenata
# 33 абе
# 32 абсолютна
# 239 абсолютно
# 47 абсурдно
# 45 аварията
# 162 август
# 54 авиолинии
# 78 австралия
# 35 австрия
# 43 автомобили
# 200 автор
# 48 автора
# 47 автори
# 56 авторите
# 64 авторитет
# 39 авторката
# 71 авторът
# 64 агент
# 105 агенти
# 36 агентите
# 35 агенции
# 123 агенция
# 96 агресия
# 39 агресията
# 32 ад
# 37 адам
# 32 адамитство
# 106 адамс
# 110 администрация
# 79 администрацията
# 70 адрес
# 113 аец
# 98 азия
# 77 айк
# 42 акад
# 47 академия
# 73 акт
# 80 активна
# 52 активни
# 82 активно
# 35 актове
# 57 актриса
# 84 актрисата
# 250 ал
# 42 албания
# 34 александров
# 165 александър
# 42 алианса
# 186 ама
# 635 америка
# 87 американска
# 277 американската
# 441 американски
# 277 американските
# 192 американския
# 101 американският
# 45 американско
# 168 американското
# 74 американци
# 200 американците
# 124 ами
# 61 амшел
# 102 анализ
# 50 анализатори
# 35 анализи
# 35 ангел
# 36 английската
# 62 английски
# 139 англия
# 44 андрей
# 84 анемия
# 31 анкетираните
# 122 анонимните
# 43 анти
# 34 антихриста
# 32 антични
# 36 античния
# 41 апаратурата
# 33 апи
# 32 апокалипсис
# 38 апостол
# 106 апостола
# 295 април
# 63 арабия
# 32 арабски
# 35 аристокрация
# 252 армия
# 125 армията
# 43 археологически
# 43 археологическо
# 34 археологът
# 44 архив
# 278 асад
# 38 асада
# 43 аспект
# 53 астролог
# 55 астрологията
# 42 астролози
# 36 ата
# 267 атака
# 146 атаката
# 131 атаки
# 36 атаките
# 32 атанас
# 65 атентат
# 106 атентати
# 43 атлантида
# 41 атмосфера
# 56 атмосферата
# 36 атомни
# 146 афганистан
# 108 африка
# 31 ахрар
# 45 бaбa
# 34 бoлният
# 625 баба
# 45 бавно
# 147 база
# 49 базата
# 32 бази
# 66 бай
# 47 баланс
# 132 балканите
# 31 балканския
# 34 балканският
# 86 бан
# 32 бани
# 144 банка
# 63 банката
# 47 банкер
# 51 банкери
# 52 банки
# 36 банско
# 63 банън
# 62 баня
# 127 барак
# 37 барселона
# 114 бастет
# 64 башар
# 430 баща
# 63 бащата
# 31 бвп
# 59 бг
# 75 бебе
# 55 бебета
# 47 бебето
# 35 беди
# 38 бедни
# 51 бедните
# 63 бедността
# 34 бедствия
# 120 бежанци
# 73 бежанците
# 37 безброй
# 42 безвъзвратно
# 94 безистена
# 62 безкрайно
# 33 безработица
# 34 безсмъртие
# 42 безспорно
# 50 безсъние
# 99 бел
# 72 бели
# 41 белите
# 102 белия
# 53 берлин
# 39 бесилката
# 40 библия
# 59 библията
# 118 бива
# 40 биват
# 65 бившата
# 41 бивши
# 33 бившите
# 133 бившия
# 155 бившият
# 36 бие
# 218 бизнес
# 68 бизнеса
# 37 бизнесмен
# 47 билдерберг
# 41 билдербергите
# 72 билдербергската
# 78 билка
# 95 билки
# 122 билките
# 42 биоенергия
# 46 битка
# 115 битката
# 133 бих
# 239 биха
# 107 бихте
# 96 бкп
# 138 блага
# 41 благо
# 57 благовест
# 35 благовеста
# 117 благовец
# 154 благовещение
# 131 благодарение
# 55 благодарни
# 41 благодарност
# 123 благоевград
# 36 благой
# 62 блатото
# 32 блеър
# 192 близки
# 202 близките
# 100 близкия
# 91 близко
# 38 близкото
# 38 близнаци
# 66 близост
# 101 близък
# 106 блиц
# 38 блога
# 75 блок
# 35 бнр
# 38 бов
# 729 бог
# 248 бога
# 71 богат
# 49 богата
# 80 богати
# 134 богатите
# 115 богатства
# 76 богатство
# 103 богатството
# 549 богиня
# 60 богинята
# 105 богове
# 120 боговете
# 70 богомилите
# 207 богородица
# 53 богу
# 39 боже
# 31 божествения
# 84 божи
# 81 божидар
# 66 божия
# 54 божията
# 31 бой
# 302 бойко
# 51 бойна
# 60 бойни
# 36 более
# 75 болен
# 204 болест
# 411 болести
# 54 болестите
# 36 болестта
# 41 боли
# 172 болка
# 49 болката
# 53 болки
# 68 болна
# 143 болни
# 72 болница
# 62 бомба
# 77 бомби
# 33 бонус
# 122 борба
# 77 борбата
# 34 борда
# 41 бори
# 97 борис
# 368 борисов
# 38 ботев
# 36 боян
# 32 брак
# 31 брани
# 136 брат
# 105 братство
# 105 братя
# 55 брекзит
# 37 бременна
# 47 британската
# 48 британски
# 58 британските
# 43 британския
# 61 британският
# 40 британците
# 43 броени
# 118 брой
# 42 броя
# 73 броят
# 39 брутална
# 87 брюксел
# 238 бсп
# 58 будет
# 120 буквално
# 32 бунт
# 56 бунтовниците
# 49 бургас
# 37 буря
# 178 буш
# 56 бъбреците
# 73 бъда
# 130 бъдем
# 190 бъдете
# 41 бъдеш
# 287 бъдеще
# 353 бъдещето
# 44 бъдещи
# 45 бъди
# 390 българи
# 158 българин
# 55 българина
# 42 българинът
# 432 българите
# 2547 българия
# 31 българка
# 48 българо
# 288 българска
# 460 българската
# 564 български
# 266 българските
# 218 българския
# 92 българският
# 63 българско
# 150 българското
# 60 бърза
# 284 бързо
# 43 бъфет
# 118 бял
# 54 бяла
# 70 бялата
# 75 бяло
# 68 бялото
# 295 бях
# 118 бяхме
# 42 вeчep
# 128 вoдa
# 66 вoдaтa
# 36 вpeмe
# 35 ва
# 81 важен
# 35 важи
# 112 важна
# 148 важни
# 97 важните
# 288 важно
# 117 важното
# 39 вазов
# 41 вайша
# 42 ваксини
# 50 валери
# 43 валута
# 32 ван
# 3023 ванга
# 32 вангел
# 64 вангелия
# 101 вариант
# 82 варна
# 42 варшава
# 254 васил
# 32 ватикана
# 32 вашата
# 63 вашето
# 272 вашингтон
# 132 вашите
# 170 вашия
# 31 вдига
# 42 вдигат
# 32 вдовици
# 275 веднага
# 286 веднъж
# 34 везувий
# 518 век
# 66 векове
# 33 вековете
# 94 велизар
# 82 велика
# 156 великата
# 112 великден
# 98 велики
# 47 великите
# 76 великия
# 32 великият
# 53 велико
# 167 великобритания
# 74 венета
# 43 венетка
# 134 вера
# 39 вериги
# 43 вероятност
# 94 версии
# 36 версиите
# 161 версия
# 47 веселин
# 51 вест
# 177 вестник
# 52 вестници
# 208 вечер
# 107 вечерта
# 53 вечеря
# 49 вечно
# 65 вещ
# 34 вещае
# 38 вещаят
# 61 вещества
# 101 вещи
# 44 взаимно
# 40 взе
# 70 взел
# 50 взела
# 120 вземат
# 93 вземе
# 44 вземете
# 68 взето
# 36 взеха
# 44 взима
# 42 взимат
# 37 взрива
# 38 взривяват
# 221 вид
# 76 вида
# 37 виден
# 40 видението
# 53 видения
# 48 виденията
# 181 видео
# 41 видеото
# 147 види
# 185 видим
# 119 видите
# 34 видиш
# 65 видове
# 60 видя
# 57 видял
# 75 видяла
# 67 видят
# 85 видях
# 55 видяхме
# 74 виж
# 275 вижда
# 86 виждал
# 32 виждала
# 54 виждали
# 161 виждам
# 82 виждаме
# 38 виждане
# 157 виждат
# 52 виждате
# 39 виждаш
# 237 вижте
# 49 визия
# 78 вийегас
# 63 вика
# 98 виктор
# 44 виктория
# 38 вино
# 43 виновен
# 34 вирус
# 60 вируси
# 59 висок
# 112 висока
# 94 високи
# 54 високите
# 145 високо
# 34 височина
# 43 висш
# 75 висши
# 43 висшите
# 44 висшия
# 38 вкара
# 77 включва
# 242 включително
# 63 вкъщи
# 47 влага
# 41 владетел
# 206 владимир
# 206 влайчо
# 441 власт
# 38 властва
# 78 власти
# 72 властите
# 36 властници
# 303 властта
# 201 влезе
# 115 влиза
# 65 влизат
# 43 влияе
# 239 влияние
# 74 влиянието
# 47 влиятелни
# 37 влязат
# 261 вместо
# 100 внезапно
# 174 внимание
# 98 вниманието
# 34 внимателни
# 48 внимателно
# 38 внук
# 36 внукът
# 33 внучето
# 75 во
# 501 вода
# 262 водата
# 36 водач
# 36 водачи
# 42 водещ
# 32 водеща
# 326 води
# 42 водка
# 40 водолей
# 117 водят
# 144 военен
# 202 военна
# 58 военната
# 238 военни
# 187 военните
# 36 военния
# 84 военно
# 46 военното
# 1950 война
# 461 войната
# 271 войни
# 113 войните
# 143 войници
# 48 войниците
# 116 войски
# 108 воля
# 38 волята
# 35 вот
# 68 впечатление
# 109 впоследствие
# 71 впрочем
# 56 враг
# 55 врагове
# 36 враговете
# 49 врата
# 106 вратата
# 55 врачка
# 34 вредни
# 217 времена
# 42 временно
# 623 времето
# 342 връзка
# 83 връзката
# 139 връзки
# 42 връзките
# 123 връх
# 156 връща
# 36 връщат
# 37 всевиждащата
# 57 вселената
# 220 всичките
# 47 всичкото
# 61 вследствие
# 476 всъщност
# 259 всякакви
# 286 всяко
# 97 втора
# 248 втората
# 122 втори
# 67 втория
# 57 вторият
# 53 вторник
# 105 второ
# 45 второто
# 35 вход
# 56 входа
# 114 вчера
# 31 въз
# 36 възгледи
# 35 въздух
# 78 въздуха
# 31 възможен
# 59 възможни
# 274 възможно
# 213 възможност
# 81 възможности
# 35 възможностите
# 72 възможността
# 39 възмущение
# 37 възниква
# 36 възприемат
# 166 възраст
# 31 възрастни
# 37 възрастните
# 43 възстановяване
# 115 вълна
# 137 вълни
# 43 вълните
# 41 външен
# 69 външна
# 71 външната
# 42 външни
# 44 външните
# 38 външно
# 158 въобще
# 31 въоръжени
# 470 въпрос
# 180 въпроса
# 174 въпроси
# 39 въпросите
# 39 въпросният
# 124 въпросът
# 119 върви
# 36 вървят
# 65 върна
# 35 върнали
# 47 върнат
# 103 върне
# 49 върнем
# 48 върти
# 74 върха
# 70 вършат
# 103 вътре
# 74 вътрешен
# 57 вътрешни
# 38 вътрешния
# 54 вътрешно
# 38 вътрешността
# 166 вяра
# 117 вярата
# 161 вярва
# 140 вярвам
# 43 вярваме
# 35 вярване
# 55 вярвания
# 187 вярват
# 38 вярвате
# 40 вярващи
# 38 вярващите
# 130 вярно
# 75 вятър
# 32 гo
# 34 гoдини
# 34 гавриил
# 68 газ
# 51 галерия
# 62 гарантира
# 47 гардиън
# 102 гейтс
# 102 ген
# 169 генерал
# 69 генералния
# 58 генетични
# 49 генетично
# 41 гений
# 37 геноцид
# 31 геополитически
# 279 георги
# 40 георгиев
# 31 георгиева
# 265 герб
# 323 германия
# 43 германската
# 31 германския
# 36 герои
# 65 герой
# 34 гимназия
# 87 гимнастика
# 191 глава
# 108 главата
# 77 глави
# 54 главите
# 63 главната
# 40 главните
# 35 главното
# 52 главоболие
# 53 глад
# 46 гласа
# 90 гласи
# 69 гласове
# 34 гласувайте
# 51 гласуваха
# 38 гласът
# 127 гледа
# 32 гледайте
# 68 гледам
# 61 гледат
# 32 гледате
# 37 гледах
# 49 гледаш
# 98 гледна
# 42 глоба
# 69 глобален
# 36 глобализацията
# 35 глобализма
# 34 глобалистите
# 81 глобална
# 39 глобалната
# 39 глобални
# 38 глобалния
# 92 глобално
# 64 глобалното
# 50 глупости
# 33 гмо
# 41 говореше
# 569 говори
# 38 говорили
# 160 говорим
# 62 говоря
# 175 говорят
# 35 года
# 300 годината
# 158 годините
# 106 годишна
# 53 годишната
# 67 годишнината
# 31 годишния
# 64 годишният
# 54 годишно
# 38 гола
# 367 големи
# 324 големите
# 103 големия
# 144 големият
# 407 голям
# 728 голяма
# 330 голямата
# 248 голямо
# 96 голямото
# 32 гонения
# 51 гора
# 113 горбачов
# 32 гордият
# 92 горе
# 126 господ
# 40 господа
# 36 господинов
# 34 господство
# 85 гости
# 58 готви
# 69 готов
# 51 готова
# 122 готови
# 48 готовност
# 39 гоце
# 39 гр
# 459 град
# 173 града
# 47 градина
# 109 градище
# 163 градове
# 54 градът
# 139 граждани
# 53 гражданин
# 75 гражданите
# 46 гражданска
# 71 гражданската
# 32 граждански
# 35 гражданство
# 49 грама
# 94 граница
# 81 границата
# 55 граници
# 77 границите
# 86 грешка
# 49 грешки
# 53 греъм
# 36 грижа
# 40 грижи
# 44 грип
# 36 гроб
# 155 гроба
# 83 гробница
# 150 гробницата
# 32 гробът
# 52 грузия
# 367 група
# 300 групата
# 106 групи
# 67 групировка
# 31 групировки
# 38 груповите
# 45 гръцки
# 95 губи
# 51 губят
# 37 гущерова
# 48 гърба
# 172 гърция
# 398 дa
# 49 дeн
# 34 дeтc
# 60 дeтeтo
# 96 дo
# 444 дава
# 37 давам
# 172 дават
# 45 давид
# 57 дадат
# 223 даде
# 45 дадем
# 33 даден
# 71 дадена
# 44 дадени
# 64 дадено
# 271 даже
# 120 дал
# 54 дала
# 147 далеч
# 33 далечната
# 52 дам
# 50 дама
# 53 дамаск
# 169 данни
# 71 дано
# 50 данъци
# 117 дарба
# 56 дарбата
# 35 даряват
# 154 дата
# 98 датата
# 60 даяна
# 111 двата
# 125 движение
# 37 движението
# 70 движения
# 34 двор
# 84 двора
# 56 двореца
# 130 де
# 68 дева
# 42 девет
# 41 дежурния
# 388 дейвид
# 85 дейли
# 116 дейност
# 37 дейности
# 38 дейността
# 154 действа
# 95 действат
# 96 действие
# 87 действително
# 92 действителност
# 198 действия
# 89 действията
# 264 декември
# 77 дела
# 56 делата
# 126 дело
# 49 делото
# 37 делчев
# 56 демиурзи
# 43 демократическата
# 31 демократична
# 145 демокрация
# 111 демокрацията
# 33 демонстрация
# 49 демонстрира
# 41 денонощието
# 260 деня
# 36 депресия
# 56 депутат
# 138 десет
# 110 десетилетия
# 54 десетина
# 161 десетки
# 44 деси
# 45 десни
# 72 детайли
# 282 дете
# 134 детето
# 105 дето
# 36 детска
# 50 детски
# 38 дефицит
# 507 деца
# 402 децата
# 34 джейкъб
# 86 джеймс
# 40 джобовете
# 222 джон
# 31 джонсън
# 188 джордж
# 53 джоунс
# 49 диагноза
# 605 диана
# 163 димитров
# 59 димитрова
# 150 димитър
# 138 димков
# 36 династия
# 55 динев
# 35 динко
# 101 директно
# 157 директор
# 35 дирекция
# 37 дискретност
# 33 дискусия
# 34 дихидроген
# 58 длъжност
# 71 для
# 56 днешен
# 34 днешна
# 34 дните
# 37 днк
# 109 добави
# 73 добавя
# 103 добрата
# 195 добри
# 88 добрите
# 31 добрич
# 50 добрия
# 61 добрият
# 151 доброто
# 46 доведат
# 263 доведе
# 64 доверие
# 50 доверието
# 37 доган
# 93 договор
# 60 договори
# 74 дойдат
# 385 дойде
# 44 докаже
# 132 доказателства
# 118 доказателство
# 47 доказва
# 89 доклад
# 40 доклада
# 45 доколко
# 47 доколкото
# 52 доктор
# 40 доктори
# 67 доктрина
# 49 доктрината
# 75 документ
# 38 документален
# 226 документи
# 40 документите
# 190 долара
# 56 долу
# 203 дом
# 270 дома
# 33 домакините
# 435 доналд
# 72 донесе
# 37 допускат
# 48 допусне
# 39 допълва
# 41 допълни
# 36 допълнително
# 283 достатъчно
# 44 достига
# 50 достигат
# 62 достъп
# 36 дотам
# 58 дотук
# 59 доц
# 136 дошли
# 73 дошъл
# 47 дпс
# 124 др
# 62 древен
# 55 древна
# 109 древни
# 98 древните
# 32 древното
# 45 дреха
# 86 дрехи
# 63 дрехите
# 132 другата
# 401 другите
# 83 другия
# 50 другият
# 308 друго
# 91 другото
# 73 дс
# 207 дуло
# 434 дума
# 76 думата
# 393 думи
# 515 думите
# 129 дупка
# 82 дупката
# 146 дух
# 53 духа
# 57 духове
# 85 духовен
# 46 духовна
# 56 духовни
# 31 духовните
# 74 духовно
# 87 духовното
# 45 духът
# 155 душа
# 122 душата
# 354 души
# 63 душите
# 32 дъжд
# 64 дълбока
# 109 дълбоко
# 70 дълбочина
# 63 дълг
# 43 дълга
# 37 дългата
# 66 дълги
# 323 дълго
# 61 дължи
# 38 дълъг
# 252 дънов
# 51 дъното
# 68 дърво
# 694 държава
# 305 държавата
# 116 държавен
# 420 държави
# 82 държавите
# 122 държавна
# 38 държавната
# 63 държавни
# 63 държавните
# 76 държавния
# 68 държат
# 134 държи
# 276 дъщеря
# 106 дъщерята
# 55 дьо
# 35 дявола
# 292 дядо
# 82 дякона
# 41 дясната
# 42 евентуална
# 41 евентуално
# 124 евреи
# 64 евреин
# 187 евреите
# 40 еврейска
# 44 еврейската
# 90 еврейски
# 84 евро
# 33 евроатлантическата
# 36 еврозоната
# 1089 европа
# 44 европейска
# 110 европейската
# 150 европейски
# 145 европейските
# 150 европейския
# 40 европейският
# 41 европейци
# 44 европейците
# 114 египет
# 62 его
# 34 единия
# 68 единият
# 55 единна
# 81 единствен
# 66 единствена
# 98 единствената
# 100 единственият
# 223 единствено
# 125 единственото
# 40 еднакво
# 131 едната
# 256 едни
# 45 едните
# 99 едновременно
# 31 едното
# 42 ежедневно
# 34 езера
# 276 език
# 104 езика
# 33 езици
# 58 ей
# 74 екипа
# 48 екипът
# 35 екологично
# 169 експедиция
# 89 експедицията
# 35 експерт
# 94 експерти
# 33 експертиза
# 36 експертите
# 46 експертът
# 39 екстрасенс
# 102 екстрасенси
# 37 ел
# 86 елемент
# 44 елементи
# 104 елена
# 219 елит
# 45 елита
# 68 елити
# 54 емил
# 37 емоции
# 40 енергетика
# 44 енергиен
# 41 енергийни
# 33 енергийно
# 428 енергия
# 72 енергията
# 54 епоха
# 116 ердоган
# 381 ес
# 57 если
# 36 естествен
# 128 естествено
# 36 есть
# 34 етаж
# 60 етап
# 103 ефект
# 37 ефекти
# 83 ешуа
# 37 жалко
# 45 жан
# 35 жасинта
# 56 же
# 104 желае
# 105 желание
# 112 желанието
# 32 желания
# 33 желаят
# 88 железни
# 46 желязната
# 81 желязо
# 80 желязото
# 757 жена
# 198 жената
# 277 жени
# 236 жените
# 44 женски
# 32 жермен
# 90 жертва
# 154 жертви
# 44 жертвите
# 35 жертвоприношения
# 66 жестока
# 114 жив
# 103 жива
# 276 живее
# 104 живеем
# 45 живеете
# 185 живеят
# 111 живи
# 253 живков
# 425 живкова
# 69 живо
# 842 живота
# 47 животни
# 33 животните
# 122 животът
# 32 живял
# 32 жизнеността
# 113 жители
# 58 жителите
# 86 жрец
# 214 жреци
# 50 жреците
# 85 жречески
# 91 журналист
# 92 журналисти
# 41 журналистите
# 193 зa
# 31 забелязвате
# 68 заболяване
# 55 заболяването
# 77 заболявания
# 34 забравя
# 47 забравяме
# 39 забрана
# 32 завещала
# 81 завинаги
# 104 зависи
# 32 зависимост
# 32 завръщането
# 118 завършва
# 41 завърши
# 32 загадка
# 33 загадки
# 57 загинат
# 37 заглавие
# 51 заглавието
# 35 заглавия
# 152 заговор
# 31 заговора
# 36 загора
# 50 загуба
# 47 загубата
# 114 загуби
# 48 загубила
# 55 загубили
# 53 задава
# 87 задача
# 54 задачата
# 162 задължително
# 37 задържат
# 52 заема
# 32 заинтригувала
# 44 закон
# 48 закона
# 115 закони
# 33 законите
# 91 зала
# 68 залата
# 35 залив
# 34 залива
# 33 заловен
# 72 зам
# 42 заместник
# 35 занапред
# 102 занимава
# 141 запад
# 134 запада
# 143 западна
# 79 западната
# 55 западни
# 74 западните
# 74 западния
# 67 западът
# 31 запазване
# 39 запазен
# 46 запазени
# 34 запази
# 41 запазят
# 46 заплата
# 143 заплаха
# 44 заплахата
# 112 заповед
# 43 запознати
# 407 започва
# 231 започват
# 39 започващи
# 187 започна
# 88 започнал
# 113 започнала
# 125 започнали
# 217 започнат
# 49 започнах
# 83 започнаха
# 309 започне
# 46 започнем
# 40 започнете
# 89 запрянов
# 36 заровен
# 44 заровени
# 39 заровено
# 38 заръчала
# 53 заслужава
# 46 заслужават
# 31 застане
# 55 застрашени
# 34 засягат
# 78 затвор
# 145 затвора
# 34 затворен
# 31 затвори
# 60 затопляне
# 146 защита
# 61 защитава
# 48 защитават
# 51 защити
# 370 заяви
# 55 заявява
# 122 звезда
# 49 звездата
# 64 звезди
# 38 звездите
# 51 звучат
# 92 звучи
# 75 здрав
# 77 здрава
# 256 здраве
# 107 здравето
# 82 здрави
# 32 здравият
# 82 здраво
# 43 зелено
# 32 зеленчуци
# 44 земен
# 74 земетресение
# 81 земетресения
# 166 земи
# 36 земния
# 41 земното
# 265 земя
# 998 земята
# 42 зима
# 43 зимата
# 40 златен
# 54 златна
# 142 злато
# 60 златолист
# 48 златото
# 71 зле
# 32 злини
# 115 зло
# 114 злото
# 35 змей
# 395 знае
# 41 знаел
# 38 знаели
# 155 знаем
# 260 знаете
# 32 знаех
# 79 знаеш
# 47 знаеше
# 226 знак
# 347 знам
# 35 знаме
# 52 знание
# 45 знанието
# 37 знания
# 86 знаци
# 40 знаците
# 231 значение
# 38 значението
# 231 значи
# 32 значителна
# 67 значително
# 69 зная
# 280 знаят
# 77 зона
# 34 зоя
# 33 зрението
# 45 зрители
# 56 зрителите
# 39 зъби
# 53 ивайло
# 342 иван
# 172 иванов
# 127 иванова
# 60 ивановден
# 50 иво
# 107 игра
# 101 играе
# 61 играта
# 45 играят
# 66 ид
# 255 идва
# 53 идването
# 217 идват
# 48 иде
# 115 идеи
# 45 идеите
# 32 идентичност
# 41 идеологически
# 72 идеология
# 121 идея
# 224 идеята
# 64 идил
# 88 иза
# 102 избор
# 41 избора
# 318 избори
# 159 изборите
# 31 избра
# 49 избран
# 36 избраха
# 42 избяга
# 137 изведнъж
# 177 известен
# 153 известна
# 56 известната
# 144 известни
# 55 известните
# 56 известния
# 47 известният
# 204 известно
# 39 извода
# 32 извор
# 38 извори
# 155 извън
# 41 извънземен
# 59 извънземна
# 134 извънземни
# 71 извънземните
# 43 извършва
# 35 извършен
# 33 извърши
# 305 изглежда
# 49 изглеждат
# 39 изгради
# 45 изграждане
# 61 изграждането
# 37 изгуби
# 122 издание
# 136 изданието
# 63 издания
# 32 издателство
# 61 издига
# 38 издигне
# 42 изисква
# 33 изкарат
# 34 изключва
# 58 изключение
# 55 изключителна
# 347 изключително
# 42 изкуствено
# 71 изкуство
# 74 изкуството
# 222 излезе
# 36 излекува
# 173 излиза
# 39 излизане
# 76 излизат
# 33 изложба
# 33 изложени
# 47 излъчване
# 35 излъчват
# 44 излязат
# 31 излязоха
# 57 измама
# 37 измерение
# 39 измислен
# 103 изненада
# 62 изненадващо
# 37 изображение
# 181 изобщо
# 36 изпере
# 39 изпитания
# 32 изпитва
# 258 използва
# 34 използвайки
# 39 използвана
# 105 използване
# 56 използването
# 75 използвани
# 51 използвано
# 196 използват
# 55 изпратени
# 96 изпрати
# 58 изпраща
# 39 изпращайте
# 32 изпълнен
# 40 изпълнена
# 87 изпълни
# 60 изпълнява
# 35 изпълняват
# 148 израел
# 43 израз
# 43 изрази
# 34 изригне
# 86 изследване
# 67 изследването
# 197 изследвания
# 40 изследовател
# 63 изследователи
# 55 изследователите
# 34 изследователят
# 32 изтегли
# 188 изток
# 107 източна
# 404 източник
# 31 източника
# 60 източници
# 34 изтъква
# 32 изход
# 193 изцяло
# 46 изчезва
# 34 изчезнали
# 61 изчезнат
# 35 изчезне
# 31 изява
# 49 изяви
# 44 изявление
# 40 изявлението
# 93 икона
# 169 иконата
# 82 икони
# 186 икономика
# 121 икономиката
# 110 икономическа
# 45 икономическата
# 196 икономически
# 57 икономическо
# 55 илиев
# 93 илия
# 361 илюминати
# 139 илюминатите
# 32 имайте
# 175 имал
# 185 имала
# 171 имали
# 367 имало
# 222 имам
# 308 имаме
# 33 иманяри
# 64 иманярска
# 31 иманярската
# 219 имате
# 116 имах
# 37 имахме
# 104 имаш
# 412 имаше
# 362 име
# 33 имел
# 31 имен
# 94 имена
# 57 имената
# 566 именно
# 439 името
# 36 имота
# 72 имоти
# 66 император
# 129 империя
# 31 империята
# 307 иначе
# 44 инвазия
# 49 инвестиции
# 90 индия
# 31 индонезия
# 77 индустрия
# 98 инж
# 74 инициатива
# 69 институт
# 76 института
# 48 институти
# 103 институции
# 47 институция
# 52 инструмент
# 230 интервю
# 37 интервюта
# 41 интервюто
# 238 интерес
# 61 интересен
# 155 интереси
# 47 интересите
# 50 интересна
# 141 интересни
# 168 интересно
# 32 интересното
# 51 интересува
# 40 интересуват
# 237 интернет
# 77 инфо
# 54 информационна
# 33 информационни
# 606 информация
# 121 информацията
# 42 инфраструктура
# 58 инцидент
# 276 ирак
# 118 иран
# 274 иса
# 31 искайте
# 46 искал
# 78 искали
# 219 искам
# 37 искаме
# 338 искат
# 122 искате
# 33 искаха
# 65 искаш
# 63 искаше
# 51 ислям
# 65 исляма
# 194 ислямска
# 32 ислямски
# 85 испания
# 46 истанбул
# 191 истина
# 325 истината
# 87 истинска
# 86 истинската
# 180 истински
# 78 истинските
# 45 истинският
# 43 истинското
# 59 истории
# 49 историк
# 51 историци
# 46 историческа
# 150 исторически
# 38 историческо
# 541 история
# 526 историята
# 32 исуж
# 74 исуз
# 447 исус
# 76 исуш
# 116 италия
# 102 ия
# 34 йероглифи
# 131 йоан
# 173 йорк
# 83 кабинет
# 52 кабинета
# 73 кадри
# 41 кадрите
# 36 кадър
# 206 кажа
# 58 кажат
# 211 каже
# 62 кажем
# 68 кажете
# 255 казал
# 301 казала
# 47 казали
# 114 казано
# 67 казаното
# 96 казах
# 68 казаха
# 37 казахстанската
# 1002 казва
# 54 казвал
# 90 казвала
# 35 казвали
# 134 казвам
# 195 казват
# 133 казваше
# 64 кайда
# 114 каквато
# 258 какви
# 136 каквито
# 254 каквото
# 96 какъвто
# 70 календар
# 37 каменни
# 40 камера
# 59 камерън
# 168 кампания
# 54 кампанията
# 108 камък
# 78 камъни
# 248 кан
# 62 канада
# 72 канал
# 118 кандидат
# 33 капитализма
# 56 капитализъм
# 34 капка
# 38 капки
# 64 кара
# 114 караджов
# 72 карат
# 80 кариера
# 51 кариерата
# 47 карл
# 243 карта
# 186 картата
# 40 карти
# 60 картина
# 34 картината
# 44 картини
# 44 картър
# 50 кастро
# 153 катаклизми
# 32 катар
# 76 катастрофа
# 52 катастрофата
# 111 катастрофи
# 78 категоричен
# 75 категорична
# 95 категорично
# 43 католическата
# 35 кафе
# 40 качества
# 31 качество
# 53 качеството
# 33 кв
# 44 квартал
# 105 кгб
# 127 ке
# 55 кейси
# 49 кемтрейлс
# 107 кенеди
# 64 киев
# 63 километра
# 68 ким
# 52 кино
# 61 кирил
# 54 киркоров
# 60 кисинджър
# 396 китай
# 31 китайската
# 32 кларк
# 40 клас
# 74 класа
# 46 клиенти
# 45 клиентите
# 52 климата
# 199 клинтън
# 111 клуб
# 42 клуба
# 32 ключ
# 42 ключови
# 143 км
# 54 кмет
# 70 кметът
# 314 книга
# 318 книгата
# 190 книги
# 62 книгите
# 134 коалиция
# 114 кого
# 191 когото
# 34 код
# 66 кое
# 112 коен
# 46 кожа
# 58 кожата
# 310 кои
# 100 кола
# 53 колата
# 43 колега
# 71 колеги
# 63 колегите
# 116 коледа
# 39 колелото
# 56 коли
# 54 колинс
# 52 количества
# 68 количество
# 398 колкото
# 42 колона
# 41 комбинация
# 61 коментар
# 65 коментара
# 207 коментари
# 202 коментира
# 33 коментирам
# 36 коментират
# 119 комисия
# 74 комитет
# 37 комитета
# 95 компании
# 92 компания
# 109 компанията
# 64 комплекс
# 170 комунизма
# 33 комунизъм
# 32 комунисти
# 49 комунистите
# 34 кон
# 33 конгрес
# 59 конгреса
# 38 конкретни
# 56 конкретно
# 74 конспиративни
# 39 конспирации
# 71 конспирация
# 37 конспирацията
# 86 контакт
# 91 контакти
# 65 континент
# 33 континента
# 304 контрол
# 116 контрола
# 104 контролира
# 113 контролират
# 46 конференция
# 254 конфликт
# 48 конфликта
# 81 конфликти
# 69 конфликтът
# 32 концепцията
# 36 концерт
# 34 концерта
# 65 конци
# 70 кончината
# 56 коньово
# 71 копие
# 32 коприва
# 49 кораб
# 43 кораби
# 60 корейския
# 68 корени
# 42 корените
# 220 корея
# 33 корнелия
# 47 корпорации
# 52 корупцията
# 40 коса
# 38 косата
# 37 коси
# 43 космически
# 74 космоса
# 51 косово
# 57 костадинова
# 64 кости
# 124 костите
# 42 кочовска
# 141 коя
# 48 краде
# 33 краен
# 482 край
# 228 крайна
# 56 крайно
# 67 крак
# 83 крака
# 53 краката
# 64 крал
# 34 кралица
# 77 кралицата
# 47 красива
# 42 красиви
# 143 красимира
# 33 красота
# 54 красотата
# 64 кратко
# 45 кратък
# 55 крачка
# 547 края
# 54 краят
# 96 кремъл
# 164 крие
# 230 криза
# 80 кризата
# 32 кризи
# 122 крим
# 33 критика
# 31 критики
# 38 крият
# 207 кръв
# 84 кръвта
# 86 кръг
# 43 кръгове
# 61 кръст
# 64 кръста
# 33 кръстен
# 35 кръстьо
# 189 кръстю
# 37 крючков
# 63 куба
# 43 кукла
# 64 култ
# 195 култура
# 88 културата
# 61 култури
# 62 културите
# 31 културни
# 54 културно
# 67 куп
# 64 купи
# 34 купите
# 44 купува
# 81 курс
# 39 курса
# 49 курск
# 35 куче
# 54 къдринка
# 44 кърпа
# 61 кърпички
# 86 късмет
# 41 късметът
# 676 късно
# 144 къща
# 184 къщата
# 40 къщи
# 51 къщите
# 35 лe
# 53 ла
# 45 лагер
# 34 лагера
# 31 лазар
# 107 лазаров
# 41 лансира
# 143 лв
# 176 лева
# 47 леви
# 445 левски
# 51 легенда
# 54 легендарната
# 40 легендата
# 42 легенди
# 38 ледовете
# 48 лежи
# 55 лек
# 63 лека
# 49 лекар
# 130 лекари
# 44 лекарите
# 98 лекарства
# 37 лекарствата
# 45 лекарство
# 47 лекарството
# 87 леко
# 198 лекува
# 76 лекуват
# 157 леля
# 58 ленин
# 58 лентата
# 39 летището
# 164 лечение
# 58 лечението
# 59 лечител
# 38 лечители
# 43 лечителка
# 104 лечителката
# 33 лечителски
# 63 либия
# 143 лидер
# 135 лидери
# 47 лидерите
# 32 ликът
# 226 лили
# 34 линеар
# 42 линии
# 167 линия
# 102 лион
# 74 липса
# 121 липсата
# 60 липсва
# 83 листата
# 60 литература
# 113 лица
# 44 лицата
# 94 лице
# 178 лицето
# 87 личен
# 38 личи
# 54 лична
# 60 лични
# 48 личния
# 263 лично
# 105 личност
# 149 личности
# 69 личността
# 45 логинова
# 39 логично
# 49 лого
# 117 лондон
# 52 лорд
# 66 лоша
# 45 лошата
# 64 лоши
# 43 лошите
# 108 лошо
# 44 лошото
# 38 луди
# 39 луис
# 32 лука
# 85 луната
# 73 лусия
# 98 лъжа
# 67 лъжи
# 39 лъжица
# 34 лъчи
# 52 льо
# 31 любимия
# 287 любов
# 176 любовта
# 52 любопитно
# 33 любопитство
# 580 людмила
# 49 ляво
# 31 лястовица
# 125 лятото
# 34 мeд
# 52 мy
# 59 ма
# 47 магазин
# 180 магдалена
# 79 магистралата
# 47 магически
# 39 магия
# 37 магията
# 33 мад
# 33 мадара
# 140 майер
# 118 майк
# 516 майка
# 80 майката
# 53 майки
# 80 майките
# 89 майкъл
# 415 макар
# 122 македония
# 33 македонският
# 71 маккейн
# 153 малка
# 55 малката
# 253 малки
# 96 малките
# 41 малкия
# 68 малкият
# 114 малкото
# 57 малцина
# 68 малцинство
# 135 малък
# 103 мама
# 116 манастир
# 89 манастира
# 72 мандат
# 52 мандата
# 32 мандатът
# 32 манипулират
# 35 манхатън
# 33 манчо
# 36 маргарет
# 41 марин
# 45 марица
# 522 мария
# 44 марк
# 45 марс
# 270 март
# 82 маса
# 40 маси
# 58 масите
# 34 маски
# 52 масло
# 100 масово
# 56 масони
# 38 масоните
# 53 масуд
# 94 мат
# 149 матара
# 62 материал
# 69 материали
# 38 материя
# 64 матката
# 97 матрона
# 67 мафия
# 45 мафията
# 50 машина
# 41 машини
# 74 мащаб
# 102 мед
# 322 медии
# 209 медиите
# 34 медийна
# 102 медицина
# 40 медицината
# 75 медицински
# 41 медия
# 42 международен
# 51 международна
# 171 международната
# 105 международни
# 60 международните
# 52 международния
# 34 мейл
# 33 мексико
# 75 мене
# 98 меркел
# 91 мерки
# 42 меркурий
# 258 месеца
# 98 месеци
# 61 месо
# 307 места
# 35 местата
# 58 местни
# 150 местните
# 103 местността
# 43 место
# 37 метеорит
# 55 метод
# 63 методи
# 118 метра
# 32 метър
# 51 механизъм
# 39 мечтата
# 114 миг
# 32 мигове
# 31 милер
# 43 милиард
# 54 милиарда
# 69 милиардер
# 39 милиардерът
# 31 милиарди
# 37 милион
# 230 милиона
# 169 милиони
# 56 мина
# 107 минава
# 138 миналата
# 43 минали
# 31 миналите
# 65 миналия
# 70 минало
# 169 миналото
# 52 минат
# 61 мине
# 33 мини
# 39 министерство
# 52 министерството
# 33 министри
# 376 министър
# 47 министърът
# 71 минута
# 126 минути
# 33 минчев
# 77 миома
# 193 мир
# 126 мира
# 117 мисия
# 99 мисията
# 60 мислене
# 267 мисли
# 43 мислим
# 100 мислите
# 272 мисля
# 145 мислят
# 41 мистериозен
# 73 мистериозна
# 64 мистериозната
# 39 мистерията
# 44 мистични
# 77 мисъл
# 47 мисълта
# 36 митове
# 35 митрополит
# 37 михаела
# 73 михаил
# 52 мишкова
# 43 мл
# 81 млад
# 43 млада
# 48 младата
# 99 млади
# 118 младите
# 41 младостта
# 99 младши
# 39 млечната
# 62 млечни
# 185 млн
# 75 млрд
# 289 мляко
# 115 млякото
# 147 мнение
# 84 мнението
# 49 мнения
# 33 многобройни
# 38 многобройните
# 51 многократно
# 33 многото
# 92 множество
# 58 мнозинство
# 40 мнозинството
# 129 мобилен
# 38 могла
# 136 могли
# 55 могло
# 97 могъл
# 95 модел
# 36 модела
# 38 мое
# 117 моето
# 45 можа
# 251 можем
# 51 может
# 173 можете
# 132 можеш
# 109 можеше
# 37 мозък
# 87 мозъка
# 42 мои
# 106 моите
# 47 мой
# 38 молитва
# 458 момент
# 42 моментално
# 91 моменти
# 56 моментът
# 389 момера
# 95 момиче
# 35 момиченца
# 32 момичето
# 69 момче
# 34 монах
# 49 монети
# 43 монопол
# 48 морган
# 383 море
# 114 морето
# 40 морските
# 378 москва
# 53 московска
# 39 московски
# 36 мохамед
# 51 мощ
# 47 мощен
# 34 мощно
# 132 моя
# 74 моят
# 135 моята
# 97 мрежа
# 42 мрежата
# 104 мрежи
# 140 музей
# 46 музея
# 131 музика
# 88 музиката
# 37 муки
# 52 мурджев
# 35 мустафа
# 37 мутафова
# 273 мутафчиев
# 39 мъгла
# 39 мъдри
# 279 мъж
# 70 мъжа
# 150 мъже
# 80 мъжете
# 37 мъжка
# 40 мъжки
# 109 мъжът
# 35 мълчание
# 34 мъртви
# 61 мъртвите
# 74 мюсюлмани
# 850 място
# 319 мястото
# 671 нa
# 34 нaй
# 91 нe
# 46 нeя
# 33 нo
# 75 наблюдава
# 43 навечерието
# 52 наводнения
# 41 навредят
# 35 навреме
# 149 навремето
# 310 навсякъде
# 42 навън
# 41 навършват
# 39 навярно
# 62 нагоре
# 74 награда
# 43 награди
# 174 надежда
# 60 надеждата
# 63 надолу
# 46 надпис
# 35 надписът
# 36 надхитрил
# 52 надявам
# 69 надяват
# 632 наистина
# 57 наказва
# 107 накара
# 291 накрая
# 44 накъде
# 101 налага
# 46 налагане
# 124 нали
# 86 налице
# 44 наличието
# 67 наложи
# 49 намалява
# 44 намаляване
# 50 намерение
# 32 намеренията
# 148 намери
# 37 намерили
# 50 намерите
# 125 намерят
# 55 намеса
# 304 намира
# 99 намират
# 48 намиращ
# 108 нанев
# 32 нанесе
# 46 наоколо
# 56 нападение
# 55 нападението
# 40 нападения
# 34 нападне
# 65 написа
# 53 написал
# 33 написана
# 42 написано
# 43 наполеон
# 67 напоследък
# 35 направена
# 69 направени
# 71 направено
# 34 направете
# 64 направил
# 43 направила
# 61 направили
# 88 направим
# 48 направите
# 48 направих
# 55 направиха
# 40 направихме
# 126 направо
# 92 направя
# 182 направят
# 98 напрежение
# 68 напрежението
# 63 напротив
# 62 напуска
# 375 напълно
# 229 нар
# 150 наред
# 59 нарежда
# 36 нареждане
# 79 нарече
# 93 наречен
# 32 наречена
# 31 наречено
# 120 нарича
# 71 наричаме
# 164 наричат
# 41 наркотици
# 386 народ
# 165 народа
# 54 народен
# 214 народи
# 90 народите
# 41 народна
# 65 народната
# 51 народни
# 86 народните
# 53 народно
# 71 народното
# 86 народът
# 67 наса
# 89 насам
# 152 население
# 177 населението
# 35 насилие
# 131 наскоро
# 35 наследници
# 65 наследство
# 38 насочена
# 82 насочени
# 60 настоява
# 49 настояване
# 41 настоящия
# 131 настъпи
# 117 нататък
# 70 натиск
# 411 нато
# 37 натрупва
# 77 наука
# 135 науката
# 40 науки
# 49 научи
# 58 научни
# 55 научно
# 104 находки
# 76 нации
# 54 национален
# 36 национализъм
# 94 национална
# 89 националната
# 45 национални
# 45 националните
# 97 националния
# 32 национално
# 44 нацистите
# 65 нация
# 96 нацията
# 44 началник
# 112 начало
# 578 началото
# 96 начело
# 786 начин
# 67 начина
# 41 начинание
# 40 начини
# 99 наш
# 49 наша
# 330 нашата
# 35 наше
# 152 нашето
# 103 наши
# 390 нашите
# 148 нашия
# 72 нашият
# 67 наяве
# 52 наясно
# 168 небето
# 48 невероятни
# 62 невероятно
# 36 невинни
# 60 невъзможно
# 35 негативно
# 78 негов
# 71 негова
# 293 неговата
# 101 негови
# 332 неговите
# 128 неговия
# 105 неговият
# 55 негово
# 189 неговото
# 43 недвижими
# 92 неделя
# 32 недоверие
# 49 недоволни
# 65 недрата
# 36 незабавно
# 34 независима
# 61 независими
# 166 независимо
# 32 неизбежно
# 40 неизвестен
# 42 неизвестни
# 48 неин
# 78 нейна
# 246 нейната
# 68 нейни
# 287 нейните
# 123 нейния
# 56 нейният
# 66 нейно
# 89 нейното
# 46 нейтън
# 357 нека
# 39 немски
# 45 необикновени
# 33 необходимата
# 32 необходими
# 169 необходимо
# 102 неоконите
# 63 непозната
# 107 непрекъснато
# 74 неприятности
# 33 нервна
# 46 нервни
# 59 неслучайно
# 48 несметни
# 81 нефт
# 142 нешка
# 537 неща
# 36 нещастие
# 55 нещастия
# 312 нещата
# 48 нибиру
# 113 нива
# 182 ниво
# 82 нивото
# 62 никак
# 87 никаква
# 214 никакви
# 68 никакво
# 151 никакъв
# 601 никога
# 131 никого
# 80 никола
# 199 николай
# 35 никсън
# 43 никъде
# 35 нима
# 75 нинова
# 46 ниска
# 43 ниски
# 42 ниските
# 32 ниско
# 53 нло
# 252 новата
# 70 новината
# 270 новини
# 41 новините
# 136 новите
# 232 новия
# 116 новият
# 177 ново
# 37 новоизбрания
# 137 новото
# 212 ноември
# 53 нож
# 40 ножове
# 99 номер
# 51 нормално
# 33 носа
# 193 носи
# 34 носите
# 46 носител
# 38 носители
# 34 носна
# 33 носни
# 134 нострадамус
# 91 носят
# 86 нощ
# 34 нощем
# 103 нощта
# 70 нср
# 198 нужда
# 70 нужни
# 130 нужно
# 63 нусра
# 192 ню
# 33 ня
# 57 някак
# 236 някаква
# 180 някакви
# 124 някакво
# 233 някакъв
# 195 някога
# 35 някого
# 33 някое
# 92 някоя
# 172 някъде
# 34 нямало
# 80 нямам
# 51 нямаме
# 320 нямат
# 34 нямате
# 37 нямах
# 199 нямаше
# 541 обама
# 50 обвинение
# 39 обвинението
# 87 обвинения
# 42 обвиненията
# 37 обвини
# 36 обвиниха
# 45 обвиняват
# 49 обед
# 32 обединена
# 33 обединени
# 51 обединение
# 38 обединените
# 114 обект
# 91 обекта
# 59 обекти
# 50 обеща
# 42 обещава
# 60 обещания
# 41 обикновен
# 44 обикновените
# 128 обикновено
# 32 обител
# 33 обич
# 69 обича
# 71 обичам
# 44 обичат
# 43 обичаше
# 33 обкръжението
# 104 област
# 48 области
# 144 областта
# 47 облечени
# 66 образ
# 49 образа
# 77 образование
# 51 образованието
# 114 обратно
# 108 обратното
# 58 обръща
# 76 обстановка
# 34 обстановката
# 49 обстоятелства
# 32 обстоятелствата
# 54 общ
# 77 обща
# 96 общества
# 32 обществена
# 68 обществеността
# 341 общество
# 276 обществото
# 39 общи
# 96 община
# 93 общност
# 245 общо
# 68 общото
# 69 обърна
# 33 обърне
# 42 обявен
# 48 обявена
# 166 обяви
# 60 обявява
# 99 обяснение
# 52 обяснението
# 100 обясни
# 33 обяснили
# 37 обясня
# 148 обяснява
# 64 обясняват
# 33 огледала
# 33 огледало
# 34 огледалото
# 94 огромен
# 77 огромна
# 60 огромната
# 115 огромни
# 60 огромно
# 89 огън
# 34 ожени
# 33 оженили
# 336 означава
# 34 означават
# 31 озовала
# 112 окаже
# 190 оказа
# 118 оказва
# 43 оказват
# 76 океан
# 36 океана
# 136 око
# 36 околната
# 38 околните
# 54 окончателно
# 34 оксфорд
# 181 октомври
# 36 оланд
# 34 олигархия
# 38 олтара
# 36 омраза
# 58 омразата
# 68 он
# 39 она
# 40 онази
# 212 онези
# 75 онзи
# 50 ония
# 61 онлайн
# 337 онова
# 201 оон
# 45 опасен
# 35 опасна
# 65 опасни
# 63 опасно
# 113 опасност
# 49 опасността
# 46 операции
# 108 операция
# 57 операцията
# 110 описва
# 281 опит
# 160 опита
# 38 опитайте
# 36 опитат
# 98 опитва
# 120 опитват
# 85 опити
# 43 опозиция
# 32 опозицията
# 59 оправи
# 42 определен
# 63 определена
# 101 определени
# 91 определено
# 54 определи
# 73 определя
# 51 определят
# 35 опустошителна
# 37 орган
# 78 органи
# 168 организации
# 187 организация
# 93 организацията
# 50 организира
# 32 организирана
# 33 организирани
# 69 организма
# 89 организъм
# 41 орден
# 47 орел
# 35 ориз
# 60 орфей
# 419 оръжие
# 256 оръжия
# 45 освобождение
# 31 освобождението
# 71 осем
# 40 осигури
# 33 осигурява
# 46 оскар
# 78 основа
# 43 основава
# 31 основан
# 50 основание
# 41 основания
# 98 основата
# 38 основателят
# 72 основен
# 49 основна
# 129 основната
# 52 основни
# 131 основните
# 51 основния
# 69 основният
# 47 основно
# 33 особена
# 301 остава
# 126 остават
# 38 оставете
# 124 остави
# 34 оставила
# 81 оставка
# 76 оставя
# 70 оставят
# 69 остана
# 40 останал
# 55 останала
# 92 останали
# 162 останалите
# 78 останало
# 67 останат
# 41 останаха
# 187 остане
# 61 останки
# 48 остри
# 35 остро
# 44 остров
# 34 осъден
# 53 осъществи
# 32 отбележи
# 44 отбеляза
# 123 отбелязва
# 40 отбор
# 70 отбрана
# 77 отбраната
# 47 отворени
# 68 отвори
# 58 отвъд
# 34 отвъдното
# 46 отвън
# 63 отвътре
# 71 отговаря
# 174 отговор
# 129 отговори
# 35 отговорите
# 135 отговорност
# 49 отговорността
# 45 отговорът
# 281 отдавна
# 46 отдел
# 72 отделни
# 38 отделните
# 58 отделно
# 34 отделя
# 45 отдолу
# 129 отец
# 115 отива
# 51 отиват
# 58 отидат
# 92 отиде
# 44 отишла
# 50 отишли
# 56 отишъл
# 32 откажем
# 43 отказа
# 45 отказал
# 58 отказва
# 68 откакто
# 230 отколкото
# 45 откри
# 60 открива
# 45 откриват
# 38 открие
# 73 открили
# 55 открит
# 111 открита
# 142 открити
# 40 откритие
# 38 открития
# 113 открито
# 36 откупи
# 65 откъде
# 51 откъдето
# 38 откъм
# 46 откъсне
# 33 отличен
# 32 отлично
# 124 отнася
# 32 отнасяме
# 33 отнасящи
# 53 отнеме
# 125 относно
# 260 отношение
# 46 отношението
# 287 отношения
# 186 отношенията
# 37 отрази
# 89 отрицателна
# 38 отрича
# 62 отрова
# 50 отрови
# 40 отслабване
# 48 отстрани
# 131 оттам
# 77 оттогава
# 97 оттук
# 37 отчасти
# 33 отчаянието
# 40 отчита
# 34 оферти
# 47 офис
# 35 офицер
# 101 офицери
# 31 официална
# 44 официалната
# 150 официално
# 50 охрана
# 39 оцелее
# 38 оцелели
# 56 оцелеят
# 231 очаква
# 31 очаквали
# 66 очакваме
# 95 очакват
# 203 очевидно
# 34 очевидци
# 149 очи
# 235 очите
# 183 пo
# 43 пpeдc
# 34 пpopoчицa
# 155 павел
# 33 павлов
# 55 пада
# 42 падането
# 55 падат
# 36 падна
# 45 падне
# 84 пазар
# 43 пазара
# 37 пазете
# 190 пази
# 47 пазите
# 32 пазят
# 121 памет
# 62 паметник
# 58 паметта
# 47 паника
# 40 панихидата
# 58 папа
# 88 папата
# 46 параклиса
# 672 пари
# 69 париж
# 148 парите
# 33 паричния
# 80 парламент
# 74 парламента
# 151 партии
# 51 партиите
# 257 партия
# 122 партията
# 34 партньор
# 92 партньори
# 34 парче
# 48 парчета
# 52 патриоти
# 41 патриотизъм
# 41 патриотите
# 64 пациенти
# 68 певица
# 97 певицата
# 87 пее
# 51 пен
# 41 пентагона
# 48 пенчева
# 228 период
# 159 периода
# 50 периоди
# 33 перли
# 32 перлите
# 42 перспектива
# 140 песен
# 84 песента
# 98 песни
# 78 песните
# 142 пет
# 89 петербург
# 137 петка
# 37 петков
# 293 петрич
# 173 петричката
# 32 петрола
# 56 петък
# 361 петър
# 41 петя
# 125 печели
# 50 пея
# 50 пиe
# 38 пие
# 79 пийте
# 76 пик
# 34 пирамиди
# 67 пирин
# 58 пирони
# 39 пироните
# 33 писал
# 35 писано
# 66 писател
# 42 писателя
# 65 писателят
# 58 писменост
# 69 писмо
# 32 писмото
# 105 пита
# 46 питам
# 47 питат
# 99 пишат
# 620 пише
# 39 пият
# 316 план
# 118 плана
# 162 планета
# 290 планетата
# 127 планина
# 59 планината
# 33 планини
# 49 планове
# 42 плановете
# 38 планът
# 69 плати
# 60 платите
# 68 плаче
# 37 плаща
# 43 плащат
# 47 племе
# 52 племена
# 52 племенницата
# 96 пловдив
# 42 плод
# 41 плода
# 48 плодове
# 43 плодовете
# 94 плоча
# 31 плочи
# 40 плюс
# 101 победа
# 158 победата
# 84 победи
# 84 поведение
# 31 поведението
# 40 поверие
# 34 поверия
# 201 повод
# 32 повреди
# 48 повтаря
# 196 поглед
# 32 погребални
# 85 погребан
# 65 погребани
# 51 погребението
# 31 погрешно
# 52 пода
# 41 подаде
# 216 подарък
# 101 подаръци
# 67 подарява
# 31 подаряваме
# 52 подводница
# 47 подводници
# 66 подготвят
# 40 подготовка
# 65 поддържа
# 35 поддържат
# 32 подем
# 39 подземните
# 41 подир
# 120 подкрепа
# 75 подкрепата
# 62 подкрепя
# 63 подкрепят
# 31 поднесен
# 99 подобен
# 94 подобна
# 214 подобни
# 147 подобно
# 49 подробно
# 46 подробности
# 36 подход
# 48 подходяща
# 39 подчерта
# 41 подчертава
# 38 пое
# 42 поема
# 43 поемат
# 51 поеме
# 70 позволи
# 63 позволява
# 92 позиции
# 141 позиция
# 75 позицията
# 35 познава
# 61 познавам
# 38 познание
# 40 познат
# 100 познати
# 71 поиска
# 53 покаже
# 99 показа
# 32 показано
# 39 показаха
# 243 показва
# 94 показват
# 39 покана
# 41 покани
# 43 поклонение
# 35 поклонници
# 87 поколение
# 43 поколения
# 126 покрай
# 73 покушение
# 96 пол
# 38 полага
# 76 поле
# 32 полезна
# 43 полезни
# 32 полет
# 60 полета
# 116 полза
# 52 ползва
# 32 политбюро
# 52 политик
# 453 политика
# 232 политиката
# 74 политики
# 233 политици
# 80 политиците
# 180 политическа
# 93 политическата
# 415 политически
# 81 политическите
# 76 политическия
# 51 политическо
# 59 политическото
# 54 полицията
# 69 половин
# 151 половина
# 70 половината
# 114 положение
# 50 положението
# 125 полуостров
# 184 получава
# 33 получаваме
# 112 получават
# 45 получат
# 179 получи
# 37 получил
# 35 получите
# 39 получих
# 101 полша
# 178 помага
# 41 помагала
# 85 помагат
# 74 помежду
# 37 помнете
# 48 помня
# 45 помогна
# 47 помогнала
# 39 помогнат
# 104 помогне
# 222 помощ
# 151 помощта
# 69 понеделник
# 193 понеже
# 236 понякога
# 45 поп
# 99 попада
# 34 попадат
# 32 попаднали
# 34 попитам
# 119 поптодорова
# 41 популярна
# 33 популярни
# 36 поражение
# 40 поражения
# 50 пореден
# 39 поредица
# 62 поредната
# 39 поредният
# 46 поредното
# 34 порои
# 54 портаитиса
# 64 портмоне
# 81 португалия
# 33 поръчка
# 32 поръчки
# 38 посветен
# 59 посветени
# 36 посвети
# 36 посети
# 42 посетил
# 42 посетители
# 33 посетителите
# 48 посещава
# 43 посещение
# 38 посещението
# 74 послание
# 41 посланието
# 117 посланик
# 69 послания
# 35 последва
# 44 последна
# 123 последната
# 44 последни
# 504 последните
# 115 последния
# 90 последният
# 85 последно
# 83 последното
# 51 последователи
# 34 последователите
# 91 последствия
# 37 последствията
# 149 посока
# 40 посолство
# 60 посочва
# 48 посочват
# 67 посочи
# 197 пост
# 89 поста
# 53 поставена
# 73 постави
# 69 поставя
# 63 поставят
# 137 постепенно
# 40 постигнат
# 62 постигне
# 174 постоянно
# 41 пострадали
# 38 пострадат
# 34 построен
# 37 построена
# 36 потвърдено
# 40 потвърждава
# 52 потенциал
# 58 поток
# 152 потомци
# 42 потомък
# 91 потоп
# 35 потопи
# 35 потъва
# 34 потънат
# 55 потъне
# 53 потърси
# 43 похвали
# 34 почва
# 45 почетен
# 103 почина
# 72 починал
# 46 починала
# 104 появата
# 191 появи
# 50 появиха
# 85 появява
# 57 появяват
# 44 появят
# 41 пояснява
# 77 пр
# 63 прав
# 144 права
# 59 правата
# 44 правда
# 43 правени
# 53 правил
# 130 правила
# 39 правилата
# 107 правилно
# 73 правим
# 127 правите
# 105 правителства
# 41 правителствата
# 469 правителство
# 214 правителството
# 48 правиш
# 217 право
# 34 православен
# 63 православна
# 46 православната
# 33 правото
# 101 правя
# 383 правят
# 62 прага
# 47 празни
# 77 празник
# 80 празника
# 69 празникът
# 74 празници
# 68 празно
# 80 празнува
# 59 празнуват
# 162 практика
# 34 практики
# 66 практически
# 33 практични
# 34 пратеник
# 42 прах
# 39 превземат
# 90 превод
# 49 преврат
# 91 превръща
# 46 превръщат
# 43 превърна
# 37 превърнат
# 111 превърне
# 46 преговори
# 33 преговорите
# 47 предава
# 62 предаване
# 72 предаването
# 39 предават
# 59 предаде
# 49 преданието
# 88 предварително
# 213 предвид
# 38 предвижда
# 33 предизборна
# 59 предизборната
# 91 предизвика
# 40 предизвиква
# 79 предимно
# 33 предимство
# 40 предишните
# 61 предлага
# 82 предлагаме
# 35 предлагат
# 50 предложение
# 32 предложения
# 63 предложи
# 76 предмет
# 129 предмети
# 37 предметите
# 50 предостави
# 41 предотврати
# 32 предпазите
# 76 предполага
# 59 предполагам
# 44 предприемач
# 64 предрекла
# 49 предрече
# 111 предрича
# 238 председател
# 39 председателя
# 43 председателят
# 88 предсказа
# 32 предсказала
# 87 предсказание
# 87 предсказанието
# 257 предсказания
# 182 предсказанията
# 120 предсказва
# 60 представа
# 36 представени
# 75 представи
# 31 представим
# 31 представите
# 99 представител
# 102 представители
# 32 представителите
# 113 представлява
# 50 представляват
# 97 представя
# 52 представят
# 198 предстои
# 34 предстоят
# 73 предстоящата
# 34 предстоящите
# 48 предупреди
# 54 предупредила
# 103 предупреждава
# 45 предупреждават
# 49 предупреждение
# 49 предци
# 33 преживява
# 37 преживявате
# 865 президент
# 316 президента
# 66 президенти
# 75 президентските
# 315 президентът
# 56 прекалено
# 38 прекарва
# 37 прекрасен
# 37 прекрасни
# 60 прекрасно
# 33 прекратяване
# 166 премиер
# 74 премиера
# 32 премина
# 52 преминава
# 43 премине
# 142 преподобна
# 34 препоръчва
# 40 преса
# 33 престижни
# 34 престой
# 62 престъпление
# 94 престъпления
# 42 престъпници
# 35 пречи
# 40 пречистващо
# 42 прибалтика
# 60 привлече
# 53 привърженици
# 34 приготвя
# 108 приема
# 113 приемат
# 33 приемаше
# 69 приеме
# 48 приемем
# 39 прието
# 172 приживе
# 45 призна
# 132 признава
# 36 признават
# 37 признак
# 41 признание
# 62 признаци
# 32 призовава
# 51 приказки
# 37 приключва
# 73 приключи
# 69 прилича
# 50 примата
# 161 пример
# 43 примери
# 65 примерно
# 78 принадлежи
# 32 принос
# 94 принц
# 40 принцеса
# 142 принцип
# 33 принципа
# 38 приписват
# 34 припомним
# 100 припомня
# 32 припомняме
# 56 природа
# 190 природата
# 116 природни
# 43 природните
# 38 пристанище
# 47 пристигането
# 32 присъедини
# 43 присъства
# 46 присъстват
# 33 присъстващи
# 42 присъствие
# 44 присъствието
# 87 притежава
# 61 притежават
# 36 притежателят
# 31 приходи
# 242 причина
# 139 причината
# 178 причини
# 53 причините
# 46 причинява
# 133 приятел
# 290 приятели
# 54 приятелите
# 45 приятелка
# 37 приятелски
# 276 проблем
# 72 проблема
# 379 проблеми
# 129 проблемите
# 74 проблемът
# 40 провал
# 44 проведе
# 41 провежда
# 37 провери
# 40 проверка
# 32 провинция
# 40 провокира
# 72 прогноза
# 84 прогнози
# 94 прогнозира
# 31 прогнозирала
# 41 прогнозите
# 39 проговори
# 173 програма
# 53 програмата
# 48 програми
# 37 продава
# 37 продават
# 37 продаде
# 119 продукт
# 114 продукти
# 31 продуцент
# 275 продължава
# 42 продължавам
# 126 продължават
# 96 продължат
# 194 продължение
# 165 продължи
# 199 проект
# 126 проекта
# 44 проекти
# 31 проектът
# 55 произведения
# 31 произвеждат
# 54 производство
# 44 производството
# 169 произход
# 76 произхода
# 36 прокопов
# 62 прокуратурата
# 44 пролет
# 109 пролетта
# 308 промени
# 70 промените
# 131 променя
# 102 променят
# 118 промяна
# 59 промяната
# 89 пропаганда
# 33 пропагандата
# 34 прорицателката
# 115 пророк
# 46 пророка
# 32 пророкувал
# 33 пророкът
# 60 пророци
# 39 пророчески
# 79 пророчества
# 96 пророчествата
# 124 пророчество
# 54 пророчеството
# 333 пророчица
# 633 пророчицата
# 34 прост
# 32 проста
# 63 прости
# 32 простичко
# 637 просто
# 115 пространство
# 71 пространството
# 190 против
# 35 противници
# 31 противоборство
# 62 противопоставяне
# 38 противопоставят
# 93 проучване
# 38 проучването
# 91 проучвания
# 36 проучванията
# 173 проф
# 44 професионална
# 81 професор
# 45 процедура
# 35 процедури
# 71 процент
# 45 процента
# 166 процес
# 70 процеси
# 38 прочете
# 50 прочетете
# 42 прочетох
# 39 прояви
# 44 проявява
# 122 пръв
# 34 пръскането
# 34 пръскат
# 83 пръст
# 49 пръстите
# 45 пръстта
# 66 пряко
# 47 психически
# 42 психично
# 31 психолози
# 39 птици
# 55 публика
# 94 публиката
# 56 публикации
# 120 публикува
# 45 публикуван
# 51 публикувана
# 43 публикувани
# 36 публикуват
# 124 публично
# 41 пускат
# 55 пуснат
# 450 путин
# 68 пълен
# 170 пълна
# 95 пълни
# 53 пълния
# 105 пълно
# 180 първа
# 180 първите
# 181 първия
# 196 първият
# 108 първоначално
# 135 първото
# 883 път
# 93 пътища
# 234 пътя
# 94 пътят
# 35 ра
# 491 работа
# 211 работата
# 42 работете
# 434 работи
# 36 работила
# 52 работим
# 33 работник
# 202 работят
# 32 равнище
# 72 радва
# 34 радвай
# 38 радвайте
# 181 радев
# 42 радиацията
# 107 радио
# 41 радиото
# 58 радост
# 84 ражда
# 36 раждане
# 57 раждането
# 70 раждат
# 114 разберат
# 118 разбере
# 44 разберем
# 102 разберете
# 468 разбира
# 56 разбирам
# 42 разбираме
# 39 разбиране
# 62 разбират
# 36 разболява
# 41 разбра
# 69 разбрах
# 100 развива
# 39 развиват
# 219 развитие
# 101 развитието
# 33 разговаря
# 120 разговор
# 60 разговори
# 41 раздава
# 146 разказа
# 39 разказали
# 299 разказва
# 33 разказвам
# 31 разкази
# 77 разкопки
# 173 разкопките
# 94 разкри
# 170 разкрива
# 35 разкриват
# 37 разкрие
# 31 разкрити
# 40 разкрития
# 175 разлика
# 39 разликата
# 78 различен
# 64 различна
# 582 различни
# 78 различните
# 72 различно
# 34 размер
# 37 разни
# 44 разпада
# 42 разпадането
# 57 разполага
# 45 разполагат
# 33 разположени
# 49 разпространението
# 52 разпространи
# 63 разпространява
# 37 разпространяват
# 33 разработка
# 35 разработки
# 32 разрешава
# 42 разрешение
# 34 разсекретим
# 72 разследване
# 32 разследването
# 81 разузнаване
# 63 разум
# 39 разумно
# 37 разходи
# 39 разчетат
# 33 разяжда
# 58 рай
# 69 район
# 160 района
# 163 райони
# 188 рак
# 66 рака
# 40 ракета
# 120 ракети
# 35 ракетната
# 33 ракия
# 33 ракът
# 99 рамките
# 43 рани
# 248 рано
# 122 раса
# 52 раси
# 62 расите
# 99 распутин
# 45 растат
# 50 расте
# 41 растежа
# 41 растения
# 41 растенията
# 61 реагира
# 113 реакция
# 54 реализация
# 45 реализацията
# 43 реализира
# 60 реална
# 61 реални
# 124 реално
# 50 реалност
# 69 реалността
# 130 революция
# 71 регион
# 164 региона
# 72 регистрация
# 402 ред
# 60 реда
# 81 редактор
# 34 редакция
# 39 редакцията
# 175 редица
# 35 редове
# 60 редовно
# 31 режещи
# 115 режим
# 60 режима
# 215 резултат
# 75 резултати
# 98 резултатите
# 63 резултатът
# 137 рейгън
# 81 река
# 39 реката
# 88 реклама
# 55 религии
# 47 религиозни
# 107 религия
# 57 религията
# 36 ремонт
# 33 рентгенови
# 32 реплика
# 44 рептили
# 52 рептилите
# 87 република
# 48 републиканската
# 39 републики
# 88 ресурси
# 33 ретингер
# 33 ретро
# 46 референдум
# 31 реформа
# 100 рецепта
# 32 рецептата
# 152 рецепти
# 32 рецептите
# 61 реч
# 84 решава
# 46 решават
# 216 решение
# 123 решението
# 134 решения
# 44 решенията
# 131 реши
# 69 решил
# 43 решила
# 34 решили
# 32 реших
# 31 решиха
# 37 решихме
# 42 ри
# 129 риба
# 41 риби
# 71 рим
# 53 римски
# 50 риск
# 31 рискувате
# 37 ритуал
# 82 ритуали
# 35 ритуалите
# 60 ричард
# 145 робева
# 74 роби
# 45 робство
# 170 робърт
# 101 род
# 97 рода
# 210 роден
# 100 родена
# 54 родени
# 72 роди
# 114 родината
# 88 родителите
# 42 родната
# 32 роднина
# 83 роднини
# 34 родния
# 32 родното
# 48 родопите
# 33 рожба
# 59 рожден
# 33 рождението
# 75 рождения
# 41 роженския
# 477 рокфелер
# 182 роля
# 161 ролята
# 42 роман
# 31 романа
# 50 роналд
# 35 роптайте
# 32 россии
# 876 ротшилд
# 34 ротшилдови
# 95 румен
# 76 румъния
# 53 русев
# 1787 русия
# 91 руска
# 298 руската
# 231 руски
# 133 руските
# 181 руския
# 94 руският
# 40 руско
# 76 руското
# 49 руснаци
# 145 руснаците
# 56 ръба
# 173 ръка
# 60 ръкавици
# 36 ръководи
# 69 ръководител
# 32 ръководство
# 54 ръководството
# 169 ръце
# 202 ръцете
# 92 рядко
# 41 рязко
# 52 саддам
# 103 сайт
# 76 сайта
# 62 сайтове
# 98 сама
# 97 самарджийска
# 350 самата
# 164 сами
# 144 самите
# 115 самия
# 183 самият
# 72 самолет
# 68 самолета
# 88 самолети
# 36 самолетите
# 45 самолетни
# 37 самолетоносач
# 41 самоличността
# 95 самото
# 40 самуил
# 80 сандански
# 71 санкт
# 41 санкции
# 60 санкциите
# 41 сапиенс
# 62 саудитска
# 2223 сащ
# 77 сблъсък
# 35 сбъдне
# 215 св
# 50 свалянето
# 33 сведения
# 1813 света
# 215 свети
# 46 светии
# 40 светилище
# 103 светица
# 37 светицата
# 46 светла
# 37 светлин
# 162 светлина
# 72 светлината
# 334 световен
# 1125 световна
# 190 световната
# 198 световни
# 106 световните
# 172 световния
# 113 световно
# 81 световното
# 34 светци
# 316 светът
# 36 свещ
# 57 свещена
# 62 свещената
# 31 свещеник
# 59 свещения
# 34 свещеният
# 53 свидетел
# 116 свидетели
# 39 свидетелстват
# 31 свински
# 57 свише
# 123 свобода
# 71 свободата
# 52 свободна
# 37 свободни
# 35 свободно
# 42 свое
# 177 своето
# 171 свои
# 540 своите
# 127 свой
# 540 своя
# 481 своята
# 32 свръх
# 142 свързан
# 102 свързана
# 219 свързани
# 83 свързано
# 77 свързва
# 67 свързват
# 73 свърши
# 1021 свят
# 58 сграда
# 35 сградата
# 42 сгради
# 37 сдс
# 42 сеанса
# 98 сеанси
# 589 себе
# 101 север
# 209 северна
# 260 севрюкова
# 32 сегашната
# 45 сегашния
# 60 седем
# 165 седмица
# 42 седмицата
# 112 седмици
# 47 седмично
# 41 сезон
# 137 секретар
# 37 секретен
# 42 секретна
# 34 секретност
# 37 секс
# 38 сектата
# 39 сектор
# 45 секунди
# 64 села
# 357 село
# 212 селото
# 39 селяните
# 127 семейства
# 374 семейство
# 256 семейството
# 42 сен
# 190 септември
# 46 сериал
# 63 сериозен
# 49 сериозна
# 175 сериозни
# 187 сериозно
# 47 серия
# 76 сестра
# 45 сетне
# 40 сещам
# 39 сибир
# 69 сигнал
# 32 сигнали
# 92 сигурен
# 42 сигурна
# 42 сигурни
# 157 сигурно
# 537 сигурност
# 95 сигурността
# 487 сила
# 177 силата
# 151 силен
# 451 сили
# 108 силите
# 156 силна
# 51 силната
# 101 силни
# 78 силните
# 301 силно
# 159 символ
# 40 символи
# 63 символизира
# 39 символизират
# 32 символична
# 71 симеонов
# 34 симптоми
# 41 симптомите
# 119 сина
# 55 синове
# 71 синтика
# 103 синът
# 32 сипе
# 38 сираци
# 33 сирене
# 73 сирии
# 113 сирийската
# 55 сирийските
# 37 сирийското
# 32 сирийци
# 797 сирия
# 454 система
# 87 системата
# 51 системи
# 34 сити
# 50 ситуации
# 228 ситуация
# 99 ситуацията
# 63 скала
# 73 скалите
# 37 скални
# 38 скандал
# 49 склонни
# 38 скрит
# 40 скрита
# 34 скрити
# 88 скрито
# 38 скрият
# 37 скръб
# 48 скъпи
# 316 слава
# 34 славата
# 54 слави
# 75 слага
# 46 слагат
# 44 следа
# 142 следва
# 69 следват
# 66 следваща
# 140 следващата
# 190 следващите
# 101 следващия
# 35 следващият
# 50 следващото
# 138 следете
# 84 следи
# 33 следната
# 39 следните
# 86 следното
# 109 следователно
# 69 следствие
# 54 сливане
# 35 сливането
# 43 сливен
# 38 слово
# 40 словото
# 48 сложат
# 115 сложи
# 35 сложни
# 43 сложно
# 47 служат
# 76 служба
# 32 службата
# 147 служби
# 111 службите
# 41 служебен
# 62 служи
# 52 служител
# 96 служители
# 44 слуз
# 46 слухове
# 145 случаи
# 430 случай
# 126 случайно
# 58 случат
# 155 случая
# 50 случаят
# 300 случва
# 74 случват
# 365 случи
# 74 случило
# 56 случилото
# 35 случка
# 101 слънце
# 219 слънцето
# 33 слънчев
# 36 слънчевата
# 57 сляпата
# 72 смее
# 45 смени
# 32 сменят
# 368 сметка
# 41 сметки
# 47 смешно
# 37 смирен
# 163 смисъл
# 278 смърт
# 32 смъртния
# 464 смъртта
# 52 смяна
# 351 смята
# 41 смятал
# 117 смятам
# 211 смятат
# 33 смятате
# 36 снизхождение
# 254 снимка
# 48 снимката
# 218 снимки
# 120 снимките
# 35 снощи
# 36 сняг
# 39 собствен
# 66 собствена
# 92 собствената
# 39 собствени
# 33 собственик
# 98 собствените
# 46 собствения
# 67 собственост
# 34 собствеността
# 36 сол
# 45 соломон
# 284 сорос
# 65 сотир
# 373 софия
# 53 социален
# 46 социална
# 54 социалната
# 63 социални
# 97 социалните
# 41 социално
# 31 сочат
# 79 сочи
# 38 спазват
# 54 спасение
# 31 спасението
# 90 спаси
# 34 спектър
# 57 спекулации
# 47 специален
# 117 специалисти
# 58 специална
# 64 специални
# 163 специално
# 137 спечели
# 56 спира
# 97 спират
# 65 списание
# 34 списанието
# 42 списък
# 34 списъка
# 152 сподели
# 35 споделил
# 59 споделила
# 32 споделите
# 163 споделя
# 31 споделяне
# 72 споделят
# 34 спокоен
# 31 спокойна
# 71 спокойно
# 35 спокойствие
# 36 спомен
# 41 спомена
# 60 споменава
# 60 спомени
# 39 спомените
# 59 спомня
# 44 спомням
# 35 споразумение
# 34 спорове
# 38 спорт
# 91 спорта
# 46 способни
# 195 способности
# 34 способността
# 45 справка
# 50 спрат
# 75 спре
# 35 спрем
# 36 спря
# 173 спрямо
# 42 спят
# 73 сравнение
# 35 сраженията
# 123 среда
# 115 средата
# 37 среди
# 43 средна
# 226 средства
# 40 средствата
# 112 средство
# 331 среща
# 34 срещал
# 31 срещали
# 38 срещат
# 129 срещата
# 142 срещи
# 59 срещите
# 36 сряда
# 259 ссср
# 41 стабилно
# 1065 става
# 36 ставало
# 32 ставаме
# 211 стават
# 45 ставаше
# 142 сталин
# 38 стаменов
# 351 стана
# 57 станал
# 43 станали
# 72 станало
# 112 станат
# 55 станаха
# 65 стандарт
# 580 стане
# 38 станем
# 45 стани
# 46 стар
# 122 стара
# 37 старата
# 77 старецът
# 91 стари
# 110 старите
# 79 стария
# 33 стартира
# 33 старши
# 84 статии
# 175 статия
# 163 статията
# 50 статут
# 39 стая
# 64 стена
# 52 стената
# 41 стени
# 270 степен
# 46 стефан
# 40 стефка
# 33 стив
# 144 стига
# 38 стигнат
# 139 стигне
# 49 стил
# 32 стихове
# 33 стичат
# 127 сто
# 120 стои
# 176 стойна
# 62 стойност
# 48 стойте
# 55 стоки
# 117 столица
# 83 столицата
# 71 столичен
# 44 стомаха
# 36 стотинка
# 112 стотици
# 33 стоян
# 63 стоянка
# 37 стоянов
# 142 стоянова
# 57 стоят
# 36 страда
# 79 страданието
# 39 страдат
# 35 страдате
# 891 страна
# 792 страната
# 297 странджа
# 623 страни
# 96 страните
# 40 страница
# 34 страницата
# 62 страници
# 42 странна
# 123 странни
# 70 странно
# 39 странното
# 32 стратегии
# 63 стратегически
# 68 стратегия
# 198 страх
# 52 страхуват
# 56 страшна
# 39 страшни
# 38 страшните
# 158 страшно
# 35 страшното
# 51 стреми
# 41 стремят
# 92 строго
# 44 строежа
# 33 строителството
# 123 струва
# 58 структура
# 45 структури
# 32 струмица
# 48 студ
# 52 студена
# 105 студената
# 34 студенти
# 44 студентите
# 42 студио
# 45 суверенна
# 81 сума
# 32 суми
# 148 сутрин
# 86 сутринта
# 43 суша
# 35 сфера
# 46 сферата
# 31 схема
# 117 сцена
# 54 сценарий
# 135 сцената
# 92 счита
# 47 считат
# 160 сша
# 35 съберат
# 36 събере
# 82 събира
# 74 събират
# 82 събитие
# 227 събития
# 130 събитията
# 78 събота
# 111 събрание
# 41 събуди
# 154 съвет
# 106 съвета
# 104 съвети
# 75 съветник
# 46 съветската
# 58 съветски
# 86 съветския
# 32 съвместно
# 33 съвпада
# 48 съвпадат
# 35 съвременната
# 434 съвсем
# 103 съд
# 52 съда
# 102 съдба
# 244 съдбата
# 42 съдействие
# 37 съди
# 133 съдържа
# 64 съдържание
# 41 съдържат
# 31 съдържащи
# 99 съединените
# 164 съжаление
# 48 съжалявам
# 127 създава
# 87 създаване
# 150 създаването
# 89 създават
# 50 създадат
# 141 създаде
# 79 създаден
# 66 създадена
# 73 създадени
# 107 съзнание
# 94 съзнанието
# 36 съкровища
# 83 съкровище
# 102 сълзи
# 82 съмнение
# 110 сън
# 44 съня
# 159 съобщава
# 35 съобщават
# 37 съобщение
# 106 съобщи
# 36 съответните
# 70 съответно
# 58 съпруг
# 125 съпруга
# 113 съпругата
# 45 съпрузите
# 32 сърбите
# 80 сърбия
# 167 сърце
# 157 сърцето
# 42 съседи
# 35 състои
# 186 състояние
# 62 състоянието
# 31 състояния
# 47 сътрудничество
# 42 съща
# 163 същата
# 90 същевременно
# 79 същества
# 36 съществено
# 82 същество
# 293 съществува
# 38 съществуване
# 70 съществуването
# 93 съществуват
# 108 същите
# 167 същия
# 45 същият
# 68 същност
# 31 същността
# 356 същото
# 351 съюз
# 43 съюза
# 74 съюзници
# 189 сякаш
# 66 сянка
# 55 тoвa
# 353 та
# 39 таен
# 38 таймс
# 237 тайна
# 141 тайната
# 230 тайни
# 141 тайните
# 170 тайно
# 35 тайното
# 46 тайнствената
# 54 так
# 344 такава
# 34 также
# 258 такова
# 151 татко
# 60 тачър
# 81 тая
# 86 тв
# 54 твоя
# 32 твоята
# 216 твърде
# 38 твърдение
# 91 твърдението
# 79 твърдения
# 32 твърденията
# 31 твърдеше
# 655 твърди
# 66 твърдо
# 244 твърдят
# 74 театър
# 192 теб
# 33 тегло
# 35 тежест
# 76 тежка
# 145 тежки
# 38 тежките
# 102 тежко
# 46 тежък
# 40 теза
# 64 тезата
# 108 текст
# 45 текста
# 39 текстове
# 33 тела
# 121 телевизия
# 69 телевизията
# 31 телеграф
# 169 телефон
# 62 телефона
# 34 телефонен
# 31 тем
# 185 тема
# 181 темата
# 99 теми
# 34 температури
# 61 тенденция
# 44 тенекеджиева
# 145 теории
# 137 теория
# 48 теорията
# 97 тепърва
# 43 терапия
# 107 територии
# 39 териториите
# 166 територия
# 191 територията
# 43 терор
# 71 тероризма
# 89 тероризъм
# 50 терористи
# 76 терористите
# 56 терористични
# 40 терористичните
# 41 техен
# 44 техни
# 117 техника
# 369 техните
# 43 технически
# 76 техния
# 59 техният
# 88 технологии
# 31 технологични
# 60 технология
# 48 тече
# 50 течение
# 48 тиллерсон
# 115 тип
# 38 типа
# 36 тихо
# 200 тия
# 48 тленните
# 90 тогавашния
# 219 тодор
# 173 тоест
# 33 ток
# 39 току
# 43 только
# 59 том
# 61 тома
# 76 томов
# 80 тон
# 56 тони
# 42 тонове
# 50 топлина
# 47 топло
# 32 торнадо
# 59 тотално
# 198 точка
# 57 точки
# 39 точната
# 39 точни
# 40 точност
# 104 тоя
# 33 трагедия
# 36 традиции
# 33 традиционната
# 42 традиционните
# 109 традиция
# 33 трае
# 33 трайно
# 40 тракийски
# 37 траките
# 99 тракия
# 65 трамп
# 53 трампа
# 32 трансформация
# 61 трапезата
# 636 трета
# 214 третата
# 164 трети
# 51 третия
# 36 третият
# 44 трето
# 33 третото
# 124 трима
# 36 тристранната
# 126 трите
# 33 трифонов
# 133 труд
# 75 труда
# 413 трудно
# 63 трудности
# 48 труман
# 55 трупа
# 45 тръби
# 40 тръгва
# 41 тръгват
# 40 тръгна
# 46 тръгнали
# 64 тръгнат
# 106 тръгне
# 1713 тръмп
# 237 трябвало
# 124 трябваше
# 45 ту
# 41 туитър
# 53 тука
# 35 тунел
# 39 туристи
# 41 туристически
# 31 турската
# 73 турски
# 33 турци
# 32 турците
# 454 турция
# 49 тъга
# 38 тъжно
# 40 тъкмо
# 74 търговия
# 47 търговията
# 90 търговски
# 128 търново
# 40 търпението
# 34 търпи
# 56 търсене
# 55 търсенето
# 50 търсеше
# 192 търси
# 32 търсите
# 180 търсят
# 141 тяло
# 273 тялото
# 41 тясно
# 86 тяхна
# 194 тяхната
# 47 тяхно
# 117 тяхното
# 103 убеден
# 41 убедена
# 58 убедени
# 38 убеди
# 33 убежища
# 48 убиват
# 48 убийства
# 47 убийство
# 84 убийството
# 68 убит
# 62 убити
# 37 уважение
# 49 увеличава
# 52 увеличаване
# 40 увеличи
# 34 уверен
# 35 уверява
# 170 удар
# 61 удара
# 146 удари
# 52 ударите
# 32 ударът
# 33 удоволствие
# 130 уж
# 69 ужас
# 65 ужасно
# 43 уже
# 57 уилям
# 43 указ
# 338 украйна
# 48 улица
# 51 улицата
# 37 улиците
# 46 ум
# 57 ума
# 34 умения
# 115 умира
# 86 умират
# 54 умишлено
# 104 умре
# 33 унгария
# 203 университет
# 58 университета
# 35 университетите
# 40 уникален
# 38 уникална
# 32 уникални
# 33 унищожаване
# 54 унищожаването
# 44 унищожени
# 53 унищожи
# 34 уорън
# 70 упорито
# 183 управление
# 128 управлението
# 145 управлява
# 108 управляват
# 34 управляващи
# 38 управляващите
# 36 управници
# 40 уреди
# 37 усещане
# 46 усещат
# 65 усилия
# 41 усилията
# 121 условия
# 42 условията
# 32 услуга
# 69 услуги
# 70 усмивка
# 63 успее
# 58 успели
# 96 успех
# 46 успехи
# 37 успешен
# 88 успешна
# 81 успешно
# 71 успеят
# 33 успокоява
# 85 успя
# 89 успява
# 71 успяват
# 39 успял
# 58 успяла
# 33 установява
# 37 устроен
# 34 уточни
# 106 участва
# 45 участвал
# 43 участвали
# 53 участват
# 101 участие
# 60 участието
# 57 участници
# 122 участниците
# 57 учен
# 142 учени
# 55 учение
# 70 учените
# 47 ученици
# 58 учи
# 45 училища
# 95 училище
# 33 учител
# 34 учители
# 72 учителя
# 42 ушев
# 124 ушите
# 242 факт
# 108 факта
# 201 факти
# 65 фактите
# 32 фактически
# 100 фактор
# 39 фактори
# 74 фактът
# 86 фалшиви
# 37 фалшивите
# 45 фамилии
# 84 фамилия
# 104 фамилията
# 31 фантазия
# 137 фатима
# 241 февруари
# 51 федерация
# 92 фейсбук
# 81 феномен
# 56 феномена
# 41 феноменалната
# 42 феноменен
# 80 феномени
# 63 феноменни
# 62 фигура
# 74 фигури
# 37 фидел
# 101 физически
# 40 физическо
# 46 фийон
# 32 филантроп
# 94 филип
# 53 филипините
# 247 филм
# 109 филма
# 66 филми
# 45 филмът
# 38 философ
# 46 финансира
# 32 финансирането
# 32 финансите
# 54 финансов
# 89 финансова
# 57 финансови
# 35 финансово
# 63 фирма
# 42 фирмата
# 91 фирми
# 33 флагман
# 38 флорида
# 137 фокус
# 50 фол
# 48 фон
# 58 фона
# 46 фондация
# 34 форбс
# 175 форма
# 134 формата
# 80 форми
# 39 франсоа
# 304 франция
# 49 французите
# 74 френски
# 43 френските
# 33 френския
# 37 френският
# 42 фронт
# 33 фронта
# 37 фьодорович
# 46 хазарския
# 89 хайтов
# 37 хакери
# 45 хакерите
# 118 хан
# 54 хаос
# 88 характер
# 32 харвард
# 37 харесала
# 40 хармония
# 46 хасково
# 32 хегемония
# 62 хенри
# 66 хераклея
# 35 хикс
# 35 хил
# 53 хилари
# 46 хилъри
# 34 хилядите
# 56 химическата
# 122 химически
# 130 химическо
# 131 хитлер
# 36 хитрец
# 36 хитрува
# 46 хляб
# 110 ход
# 43 хода
# 59 ходи
# 59 ходил
# 48 ходят
# 32 холивуд
# 41 хомо
# 2397 хора
# 31 хорасио
# 1842 хората
# 40 хормон
# 81 хормони
# 77 хороскоп
# 78 хотел
# 36 хр
# 141 храм
# 145 храма
# 45 храмове
# 100 храна
# 73 храната
# 47 хранене
# 95 храни
# 38 храните
# 52 христа
# 89 християни
# 35 християнин
# 55 християните
# 78 християнски
# 31 християнство
# 58 християнството
# 180 христо
# 150 христос
# 55 хрушчов
# 37 хубав
# 33 хубава
# 57 хубавите
# 159 хубаво
# 36 хубавото
# 51 художествена
# 38 художествената
# 40 хълма
# 193 цар
# 130 царичина
# 33 царичината
# 41 царя
# 107 цвете
# 80 цветове
# 56 цветя
# 55 цветята
# 59 цвят
# 419 цел
# 241 цели
# 73 целите
# 484 целия
# 75 целият
# 195 целта
# 73 цена
# 108 цената
# 34 цени
# 44 цените
# 31 ценни
# 100 ценности
# 83 централна
# 67 централната
# 52 центрове
# 255 център
# 139 центъра
# 51 центърът
# 37 церемонии
# 35 церемонията
# 59 цивилизации
# 213 цивилизация
# 43 цивилизацията
# 33 цивилни
# 32 цигани
# 53 циганите
# 38 цикъл
# 48 цитат
# 58 цитира
# 59 цитиран
# 56 цитирана
# 39 цк
# 160 цру
# 32 цум
# 212 църква
# 228 църквата
# 164 цял
# 189 цяла
# 540 цялата
# 152 цяло
# 246 цялото
# 35 цяр
# 164 чe
# 36 чай
# 218 чак
# 79 чака
# 53 чакат
# 52 чарлз
# 82 час
# 77 часове
# 50 часовник
# 32 часовниците
# 1163 част
# 151 части
# 56 частици
# 63 чаша
# 62 червен
# 44 червени
# 49 червено
# 64 черен
# 61 черна
# 52 черни
# 189 черно
# 47 чернобил
# 92 чест
# 39 чества
# 41 честно
# 31 чета
# 47 четвърти
# 41 четвъртък
# 43 чете
# 78 четете
# 141 четири
# 51 четирите
# 68 чието
# 137 чиито
# 78 чийто
# 32 чиновници
# 56 число
# 52 чист
# 90 чиста
# 66 чисти
# 110 чисто
# 48 читатели
# 45 читателите
# 91 чиято
# 236 член
# 47 членки
# 113 членове
# 118 членовете
# 1507 човек
# 348 човека
# 174 човекът
# 46 човечество
# 375 човечеството
# 57 човешка
# 124 човешката
# 143 човешки
# 32 човешките
# 69 човешкия
# 34 човешко
# 50 човешкото
# 251 что
# 37 чтобы
# 47 чува
# 38 чувал
# 33 чували
# 109 чувства
# 33 чувстват
# 67 чувство
# 32 чувството
# 140 чудеса
# 41 чудесата
# 60 чудно
# 120 чудо
# 32 чудотворната
# 82 чудото
# 126 чужбина
# 45 чужда
# 51 чуждестранни
# 136 чужди
# 41 чуждите
# 45 чул
# 34 чула
# 35 чули
# 39 чух
# 45 чърчил
# 37 шалом
# 42 шам
# 77 шанс
# 39 швейцария
# 35 шега
# 69 шест
# 151 шеф
# 39 шефа
# 45 шефът
# 32 широк
# 77 широко
# 51 шифър
# 49 школа
# 35 шок
# 36 шокира
# 92 шоу
# 49 шоуто
# 107 щe
# 88 щаб
# 99 щастие
# 62 щастието
# 71 щастлив
# 61 щастлива
# 32 щастливия
# 51 щата
# 126 щати
# 72 щатите
# 42 щели
# 132 щеше
# 46 щит
# 166 що
# 58 щото
# 48 щял
# 54 щяло
# 61 щяха
# 44 ъгъл
# 34 ът
# 125 это
# 39 этом
# 62 юг
# 177 югославия
# 39 юдаизма
# 204 южна
# 44 южната
# 187 юли
# 122 юни
# 56 юнкер
# 75 ябълка
# 46 ябълката
# 31 яви
# 49 явила
# 90 явление
# 45 явлението
# 60 явления
# 127 явно
# 47 явява
# 32 ядат
# 87 яде
# 89 ядрен
# 107 ядрена
# 34 ядрената
# 146 ядрени
# 76 ядрено
# 36 яжте
# 56 яйца
# 58 якоб
# 103 ямбол
# 313 януари
# 147 япония
# 34 японски
# 52 ясна
# 530 ясно
# 80 ясновидецът
# 94 ясновидка
# 93 ясновидката
# 32 ясновидци

# %%
from sklearn.ensemble import RandomForestClassifier

forest = RandomForestClassifier(n_estimators = 100) 
forest = forest.fit( X_train_features, X_train["fake_news_score_binary"] )

# %%
X_test_features  = create_features(X_test)

# %%
from sklearn.cross_validation import cross_val_score
np.mean(cross_val_score(forest, X_test_features, y_test, cv=30))
# Out:
# 0.69657971014492759
